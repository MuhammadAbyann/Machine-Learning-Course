# %% [markdown]
# # IMPORT LIBRARIES

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import pandas as pd

import re
import string
import os

# %% [markdown]
# # DATA PREP

# %%
def load_dataset(file_path):
    """
    Membaca file imdb_labelled.txt
    Format tiap baris: <teks>\t<label>
    """
    texts = []
    labels = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line_split = line.strip().split('\t')
            if len(line_split) == 2:
                text, label = line_split
                texts.append(text)
                labels.append(int(label))
    return texts, labels

# %%
def text_cleaning(text):
    """
    Membersihkan teks sederhana: lower, hapus angka & tanda baca, dsb.
    """
    text = text.lower()
    text = re.sub(r'[%s]' % re.escape(string.punctuation), ' ', text)  # hapus tanda baca
    text = re.sub(r'\d+', '', text)  # hapus angka
    text = re.sub(r'\s+', ' ', text)  # hapus spasi berlebih
    text = text.strip()
    return text

# %%
def build_vocab(cleaned_texts, min_freq=1):
    """
    Membuat word2idx sederhana berdasarkan frekuensi kemunculan kata.
    min_freq = minimal frekuensi agar kata dimasukkan ke vocab
    """
    freq_dict = {}
    for text in cleaned_texts:
        for word in text.split():
            freq_dict[word] = freq_dict.get(word, 0) + 1

    # sort by frequency
    sorted_words = sorted(freq_dict.items(), key=lambda x: x[1], reverse=True)

    # Buat word2idx, sisipkan token khusus <PAD> dan <UNK>
    word2idx = {'<PAD>':0, '<UNK>':1}
    idx = 2
    for word, freq in sorted_words:
        if freq >= min_freq:
            word2idx[word] = idx
            idx += 1
    return word2idx

# %%
def encode_text(text, word2idx, max_len=50):
    """
    Mengubah teks menjadi list of token-id (integer),
    dan memotong/padding sampai max_len.
    """
    tokens = text.split()
    encoded = []
    for token in tokens:
        encoded.append(word2idx.get(token, word2idx['<UNK>']))
    # potong jika panjang > max_len
    encoded = encoded[:max_len]
    # padding jika panjang < max_len
    if len(encoded) < max_len:
        encoded += [word2idx['<PAD>']] * (max_len - len(encoded))
    return encoded

# %%
class IMDBDataset(Dataset):
    def __init__(self, texts, labels, word2idx, max_len=50):
        self.texts = texts
        self.labels = labels
        self.word2idx = word2idx
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        encoded_text = encode_text(text, self.word2idx, self.max_len)
        return torch.LongTensor(encoded_text), torch.LongTensor([label])

# %% [markdown]
# # BIDIRECTIONAL RNN MODEL DEFINITION

# %%
class BiRNNClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim=128, hidden_size=128, num_layers=1,
                 pooling='max', num_classes=2):
        super(BiRNNClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)

        # RNN bidirectional
        self.rnn = nn.RNN(
            input_size=embed_dim,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            bidirectional=True,     # <-- Bidirectional diaktifkan
            nonlinearity='tanh',
            dropout=0.0
        )

        self.pooling = pooling  # 'max' or 'avg'
        # karena bidirectional, hidden size output = hidden_size * 2
        self.fc = nn.Linear(hidden_size * 2, num_classes)

    def forward(self, x):
        # x shape: (batch_size, seq_len)
        embedded = self.embedding(x)  # (batch_size, seq_len, embed_dim)
        rnn_out, h_n = self.rnn(embedded)  # (batch_size, seq_len, hidden_size*2)

        if self.pooling == 'max':
            # MaxPooling over seq_len
            pooled, _ = torch.max(rnn_out, dim=1)  # (batch_size, hidden_size*2)
        else:
            # AvgPooling
            pooled = torch.mean(rnn_out, dim=1)    # (batch_size, hidden_size*2)

        logits = self.fc(pooled)  # (batch_size, num_classes)
        return logits

# %% [markdown]
# # TRAINING & EVALUATION UTILS

# %%
def calculate_accuracy(y_pred, y_true):
    predicted = torch.argmax(y_pred, dim=1)
    correct = (predicted == y_true.view(-1)).sum().item()
    total = y_true.size(0)
    return correct / total

# %%
def train_one_epoch(model, dataloader, optimizer, criterion, device='cpu'):
    model.train()
    running_loss = 0.0
    running_acc = 0.0
    for x_batch, y_batch in dataloader:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        outputs = model(x_batch)
        loss = criterion(outputs, y_batch.view(-1))
        loss.backward()
        optimizer.step()

        acc = calculate_accuracy(outputs, y_batch)
        running_loss += loss.item() * x_batch.size(0)
        running_acc  += acc * x_batch.size(0)

    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = running_acc / len(dataloader.dataset)
    return epoch_loss, epoch_acc

# %%
def validate_one_epoch(model, dataloader, criterion, device='cpu'):
    model.eval()
    running_loss = 0.0
    running_acc = 0.0
    with torch.no_grad():
        for x_batch, y_batch in dataloader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            outputs = model(x_batch)
            loss = criterion(outputs, y_batch.view(-1))

            acc = calculate_accuracy(outputs, y_batch)
            running_loss += loss.item() * x_batch.size(0)
            running_acc  += acc * x_batch.size(0)

    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = running_acc / len(dataloader.dataset)
    return epoch_loss, epoch_acc

# %% [markdown]
# # EARLY STOPPING

# %%
class EarlyStopping:
    def __init__(self, patience=5, delta=0.0):
        self.patience = patience
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
        self.delta = delta

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss > self.best_loss - self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.counter = 0

# %% [markdown]
# # TRAIN N EVALUATE

# %%
def train_and_evaluate(model,
                       train_loader,
                       val_loader,
                       optimizer,
                       scheduler,
                       criterion,
                       epochs=10,
                       patience=5,
                       device='cpu'):

    early_stopper = EarlyStopping(patience=patience)

    best_val_loss = float('inf')
    best_model_state = None

    for epoch in range(1, epochs+1):
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion, device)
        val_loss, val_acc = validate_one_epoch(model, val_loader, criterion, device)

        # Update scheduler (misal ReduceLROnPlateau)
        if scheduler is not None:
            scheduler.step(val_loss)

        print(f"Epoch [{epoch}/{epochs}] | "
              f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} | "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")

        # Simpan model terbaik
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = model.state_dict()

        # Early Stopping
        early_stopper(val_loss)
        if early_stopper.early_stop:
            print("Early stopping triggered!")
            break

    # load model terbaik
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
    return model

# %% [markdown]
# # EXPERIMENT CONFIG

# %%
from google.colab import drive
import pandas as pd
from google.colab import files
drive.mount('/content/drive')

FILE_PATH = "/content/drive/MyDrive/Machine Learning/imdb_labelled.txt"
BATCH_SIZE = 32
MAX_LEN = 50
EMBED_DIM = 128
DEVICE = 'cpu'  # 'cuda' jika GPU tersedia

HIDDEN_SIZES = [64, 128]
POOLINGS = ['max', 'avg']
OPTIMIZERS = ['SGD', 'RMSProp', 'Adam']
EPOCHS_LIST = [5, 50, 100, 250, 350]

PATIENCE = 5
# Out:
# Mounted at /content/drive

# %% [markdown]
# # MAIN EXPERIMENT (BIDIRECTIONAL RNN) WITH LOGGING

# %%
def main_experiment_birnn():
    # 1. Load & preprocess
    texts, labels = load_dataset(FILE_PATH)
    cleaned_texts = [text_cleaning(t) for t in texts]
    word2idx = build_vocab(cleaned_texts, min_freq=1)
    vocab_size = len(word2idx)

    # 2. Split data
    train_texts, val_texts, train_labels, val_labels = train_test_split(
        cleaned_texts, labels, test_size=0.2, random_state=42
    )

    # 3. Dataset & DataLoader
    train_dataset = IMDBDataset(train_texts, train_labels, word2idx, max_len=MAX_LEN)
    val_dataset   = IMDBDataset(val_texts,   val_labels,   word2idx, max_len=MAX_LEN)

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False)

    # 4. Criterion
    criterion = nn.CrossEntropyLoss()

    # 5. Logging
    results = []

    # 6. Loop experiment
    for hidden_size in HIDDEN_SIZES:
        for pooling in POOLINGS:
            for opt_name in OPTIMIZERS:
                for epochs in EPOCHS_LIST:
                    print("================================================")
                    print(f"[INFO] hidden_size={hidden_size}, pooling={pooling}, "
                          f"optimizer={opt_name}, epochs={epochs}")

                    # 6.1 Build model
                    model = BiRNNClassifier(
                        vocab_size=vocab_size,
                        embed_dim=EMBED_DIM,
                        hidden_size=hidden_size,
                        num_layers=1,  # jika mau lebih deep, ganti 2-3 dsb
                        pooling=pooling,
                        num_classes=2
                    ).to(DEVICE)

                    # 6.2 Optimizer
                    if opt_name == 'SGD':
                        optimizer = optim.SGD(model.parameters(), lr=0.01)
                    elif opt_name == 'RMSProp':
                        optimizer = optim.RMSprop(model.parameters(), lr=0.001)
                    else:  # Adam
                        optimizer = optim.Adam(model.parameters(), lr=0.001)

                    # 6.3 Scheduler
                    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)

                    # 6.4 Train & Evaluate
                    trained_model = train_and_evaluate(
                        model,
                        train_loader,
                        val_loader,
                        optimizer,
                        scheduler,
                        criterion,
                        epochs=epochs,
                        patience=PATIENCE,
                        device=DEVICE
                    )

                    # 6.5 Cek final performance
                    final_train_loss, final_train_acc = validate_one_epoch(trained_model, train_loader, criterion, DEVICE)
                    final_val_loss,   final_val_acc   = validate_one_epoch(trained_model, val_loader,   criterion, DEVICE)

                    # 6.6 Simpan ke results
                    results.append({
                        "hidden_size": hidden_size,
                        "pooling": pooling,
                        "optimizer": opt_name,
                        "epochs": epochs,
                        "final_train_loss": final_train_loss,
                        "final_train_acc": final_train_acc,
                        "final_val_loss": final_val_loss,
                        "final_val_acc": final_val_acc
                    })

                    print("================================================\n")

    # 7. Buat DataFrame & Simpan CSV
    df_results = pd.DataFrame(results)
    df_results.to_csv('experiment_birnn_results.csv', index=False)
    print("Hasil eksperimen telah disimpan dalam 'experiment_birnn_results.csv'.")

    # Jika ingin mendownload otomatis (Colab):
    files.download('experiment_birnn_results.csv')

if __name__ == "__main__":
    main_experiment_birnn()
# Out:
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=SGD, epochs=5
# Epoch [1/5] | Train Loss: 0.7027, Train Acc: 0.4925 | Val Loss: 0.7042, Val Acc: 0.4800
# Epoch [2/5] | Train Loss: 0.6948, Train Acc: 0.5050 | Val Loss: 0.7130, Val Acc: 0.4650
# Epoch [3/5] | Train Loss: 0.6953, Train Acc: 0.5162 | Val Loss: 0.7092, Val Acc: 0.4700
# Epoch [4/5] | Train Loss: 0.6912, Train Acc: 0.5363 | Val Loss: 0.7012, Val Acc: 0.4850
# Epoch [5/5] | Train Loss: 0.6884, Train Acc: 0.5288 | Val Loss: 0.6868, Val Acc: 0.5500
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=SGD, epochs=50
# Epoch [1/50] | Train Loss: 0.7158, Train Acc: 0.4888 | Val Loss: 0.6934, Val Acc: 0.5450
# Epoch [2/50] | Train Loss: 0.6966, Train Acc: 0.5250 | Val Loss: 0.6946, Val Acc: 0.4750
# Epoch [3/50] | Train Loss: 0.6985, Train Acc: 0.5100 | Val Loss: 0.6914, Val Acc: 0.5550
# Epoch [4/50] | Train Loss: 0.6941, Train Acc: 0.5050 | Val Loss: 0.6908, Val Acc: 0.5500
# Epoch [5/50] | Train Loss: 0.6923, Train Acc: 0.5112 | Val Loss: 0.6982, Val Acc: 0.4550
# Epoch [6/50] | Train Loss: 0.6924, Train Acc: 0.5288 | Val Loss: 0.7082, Val Acc: 0.4800
# Epoch [7/50] | Train Loss: 0.6884, Train Acc: 0.5312 | Val Loss: 0.7250, Val Acc: 0.4750
# Epoch [8/50] | Train Loss: 0.6870, Train Acc: 0.5375 | Val Loss: 0.6987, Val Acc: 0.4700
# Epoch [9/50] | Train Loss: 0.6850, Train Acc: 0.5400 | Val Loss: 0.6932, Val Acc: 0.4800
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=SGD, epochs=100
# Epoch [1/100] | Train Loss: 0.7023, Train Acc: 0.4775 | Val Loss: 0.6952, Val Acc: 0.4950
# Epoch [2/100] | Train Loss: 0.6974, Train Acc: 0.5000 | Val Loss: 0.6910, Val Acc: 0.5600
# Epoch [3/100] | Train Loss: 0.6972, Train Acc: 0.4963 | Val Loss: 0.7212, Val Acc: 0.4650
# Epoch [4/100] | Train Loss: 0.6976, Train Acc: 0.5000 | Val Loss: 0.6870, Val Acc: 0.5500
# Epoch [5/100] | Train Loss: 0.6915, Train Acc: 0.5288 | Val Loss: 0.6858, Val Acc: 0.5400
# Epoch [6/100] | Train Loss: 0.6862, Train Acc: 0.5487 | Val Loss: 0.6901, Val Acc: 0.5150
# Epoch [7/100] | Train Loss: 0.6841, Train Acc: 0.5687 | Val Loss: 0.7088, Val Acc: 0.4800
# Epoch [8/100] | Train Loss: 0.6847, Train Acc: 0.5663 | Val Loss: 0.7055, Val Acc: 0.4850
# Epoch [9/100] | Train Loss: 0.6802, Train Acc: 0.5400 | Val Loss: 0.6837, Val Acc: 0.5650
# Epoch [10/100] | Train Loss: 0.6780, Train Acc: 0.5650 | Val Loss: 0.6856, Val Acc: 0.5400
# Epoch [11/100] | Train Loss: 0.6774, Train Acc: 0.5687 | Val Loss: 0.6850, Val Acc: 0.5550
# Epoch [12/100] | Train Loss: 0.6733, Train Acc: 0.5863 | Val Loss: 0.6812, Val Acc: 0.5550
# Epoch [13/100] | Train Loss: 0.6733, Train Acc: 0.5825 | Val Loss: 0.6801, Val Acc: 0.5750
# Epoch [14/100] | Train Loss: 0.6734, Train Acc: 0.5938 | Val Loss: 0.6842, Val Acc: 0.5300
# Epoch [15/100] | Train Loss: 0.6712, Train Acc: 0.6038 | Val Loss: 0.6806, Val Acc: 0.5800
# Epoch [16/100] | Train Loss: 0.6703, Train Acc: 0.5950 | Val Loss: 0.6889, Val Acc: 0.5050
# Epoch [17/100] | Train Loss: 0.6679, Train Acc: 0.5913 | Val Loss: 0.6797, Val Acc: 0.5750
# Epoch [18/100] | Train Loss: 0.6671, Train Acc: 0.6412 | Val Loss: 0.6791, Val Acc: 0.5900
# Epoch [19/100] | Train Loss: 0.6659, Train Acc: 0.6288 | Val Loss: 0.6806, Val Acc: 0.5350
# Epoch [20/100] | Train Loss: 0.6650, Train Acc: 0.6300 | Val Loss: 0.6832, Val Acc: 0.5150
# Epoch [21/100] | Train Loss: 0.6650, Train Acc: 0.6112 | Val Loss: 0.6827, Val Acc: 0.5150
# Epoch [22/100] | Train Loss: 0.6635, Train Acc: 0.6525 | Val Loss: 0.6823, Val Acc: 0.5100
# Epoch [23/100] | Train Loss: 0.6636, Train Acc: 0.6500 | Val Loss: 0.6817, Val Acc: 0.5450
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=SGD, epochs=250
# Epoch [1/250] | Train Loss: 0.7016, Train Acc: 0.4963 | Val Loss: 0.7034, Val Acc: 0.4750
# Epoch [2/250] | Train Loss: 0.6947, Train Acc: 0.5050 | Val Loss: 0.6987, Val Acc: 0.4800
# Epoch [3/250] | Train Loss: 0.6922, Train Acc: 0.5375 | Val Loss: 0.6852, Val Acc: 0.5600
# Epoch [4/250] | Train Loss: 0.6919, Train Acc: 0.5038 | Val Loss: 0.6944, Val Acc: 0.4900
# Epoch [5/250] | Train Loss: 0.6907, Train Acc: 0.5262 | Val Loss: 0.6843, Val Acc: 0.5450
# Epoch [6/250] | Train Loss: 0.6877, Train Acc: 0.5425 | Val Loss: 0.7169, Val Acc: 0.4750
# Epoch [7/250] | Train Loss: 0.6862, Train Acc: 0.5350 | Val Loss: 0.6973, Val Acc: 0.5100
# Epoch [8/250] | Train Loss: 0.6811, Train Acc: 0.5525 | Val Loss: 0.6836, Val Acc: 0.5000
# Epoch [9/250] | Train Loss: 0.6734, Train Acc: 0.5900 | Val Loss: 0.6813, Val Acc: 0.5800
# Epoch [10/250] | Train Loss: 0.6777, Train Acc: 0.5938 | Val Loss: 0.6786, Val Acc: 0.5800
# Epoch [11/250] | Train Loss: 0.6740, Train Acc: 0.5725 | Val Loss: 0.6853, Val Acc: 0.5250
# Epoch [12/250] | Train Loss: 0.6728, Train Acc: 0.5775 | Val Loss: 0.6918, Val Acc: 0.5100
# Epoch [13/250] | Train Loss: 0.6700, Train Acc: 0.5725 | Val Loss: 0.6759, Val Acc: 0.5800
# Epoch [14/250] | Train Loss: 0.6618, Train Acc: 0.5988 | Val Loss: 0.7059, Val Acc: 0.4950
# Epoch [15/250] | Train Loss: 0.6652, Train Acc: 0.6038 | Val Loss: 0.6766, Val Acc: 0.5350
# Epoch [16/250] | Train Loss: 0.6636, Train Acc: 0.6250 | Val Loss: 0.6754, Val Acc: 0.5350
# Epoch [17/250] | Train Loss: 0.6580, Train Acc: 0.6312 | Val Loss: 0.6731, Val Acc: 0.5550
# Epoch [18/250] | Train Loss: 0.6532, Train Acc: 0.6250 | Val Loss: 0.6721, Val Acc: 0.5450
# Epoch [19/250] | Train Loss: 0.6546, Train Acc: 0.6375 | Val Loss: 0.6710, Val Acc: 0.5450
# Epoch [20/250] | Train Loss: 0.6470, Train Acc: 0.6350 | Val Loss: 0.6708, Val Acc: 0.5550
# Epoch [21/250] | Train Loss: 0.6440, Train Acc: 0.6462 | Val Loss: 0.6742, Val Acc: 0.5450
# Epoch [22/250] | Train Loss: 0.6420, Train Acc: 0.6800 | Val Loss: 0.6941, Val Acc: 0.5150
# Epoch [23/250] | Train Loss: 0.6397, Train Acc: 0.6787 | Val Loss: 0.6660, Val Acc: 0.5850
# Epoch [24/250] | Train Loss: 0.6354, Train Acc: 0.6687 | Val Loss: 0.6670, Val Acc: 0.5600
# Epoch [25/250] | Train Loss: 0.6312, Train Acc: 0.6700 | Val Loss: 0.6820, Val Acc: 0.5450
# Epoch [26/250] | Train Loss: 0.6279, Train Acc: 0.6863 | Val Loss: 0.6673, Val Acc: 0.5300
# Epoch [27/250] | Train Loss: 0.6244, Train Acc: 0.7350 | Val Loss: 0.6646, Val Acc: 0.5600
# Epoch [28/250] | Train Loss: 0.6222, Train Acc: 0.7325 | Val Loss: 0.6645, Val Acc: 0.5600
# Epoch [29/250] | Train Loss: 0.6195, Train Acc: 0.7450 | Val Loss: 0.6631, Val Acc: 0.5700
# Epoch [30/250] | Train Loss: 0.6189, Train Acc: 0.7525 | Val Loss: 0.6623, Val Acc: 0.5700
# Epoch [31/250] | Train Loss: 0.6150, Train Acc: 0.7650 | Val Loss: 0.6598, Val Acc: 0.6050
# Epoch [32/250] | Train Loss: 0.6141, Train Acc: 0.7225 | Val Loss: 0.6749, Val Acc: 0.5450
# Epoch [33/250] | Train Loss: 0.6132, Train Acc: 0.7350 | Val Loss: 0.6682, Val Acc: 0.5500
# Epoch [34/250] | Train Loss: 0.6100, Train Acc: 0.7712 | Val Loss: 0.6588, Val Acc: 0.5950
# Epoch [35/250] | Train Loss: 0.6086, Train Acc: 0.7588 | Val Loss: 0.6636, Val Acc: 0.5650
# Epoch [36/250] | Train Loss: 0.6051, Train Acc: 0.7738 | Val Loss: 0.6567, Val Acc: 0.6200
# Epoch [37/250] | Train Loss: 0.6018, Train Acc: 0.7338 | Val Loss: 0.6576, Val Acc: 0.5950
# Epoch [38/250] | Train Loss: 0.6014, Train Acc: 0.7412 | Val Loss: 0.6643, Val Acc: 0.5450
# Epoch [39/250] | Train Loss: 0.6015, Train Acc: 0.7750 | Val Loss: 0.6621, Val Acc: 0.5800
# Epoch [40/250] | Train Loss: 0.5966, Train Acc: 0.7887 | Val Loss: 0.6582, Val Acc: 0.5650
# Epoch [41/250] | Train Loss: 0.5956, Train Acc: 0.7925 | Val Loss: 0.6599, Val Acc: 0.5600
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=SGD, epochs=350
# Epoch [1/350] | Train Loss: 0.6940, Train Acc: 0.5088 | Val Loss: 0.6976, Val Acc: 0.4950
# Epoch [2/350] | Train Loss: 0.6936, Train Acc: 0.5062 | Val Loss: 0.7083, Val Acc: 0.4700
# Epoch [3/350] | Train Loss: 0.6919, Train Acc: 0.5100 | Val Loss: 0.7067, Val Acc: 0.4750
# Epoch [4/350] | Train Loss: 0.6914, Train Acc: 0.4975 | Val Loss: 0.6942, Val Acc: 0.5050
# Epoch [5/350] | Train Loss: 0.6867, Train Acc: 0.5275 | Val Loss: 0.6974, Val Acc: 0.4800
# Epoch [6/350] | Train Loss: 0.6864, Train Acc: 0.5525 | Val Loss: 0.6991, Val Acc: 0.5400
# Epoch [7/350] | Train Loss: 0.6819, Train Acc: 0.5613 | Val Loss: 0.6911, Val Acc: 0.5100
# Epoch [8/350] | Train Loss: 0.6802, Train Acc: 0.5400 | Val Loss: 0.6922, Val Acc: 0.5300
# Epoch [9/350] | Train Loss: 0.6867, Train Acc: 0.5675 | Val Loss: 0.7167, Val Acc: 0.4850
# Epoch [10/350] | Train Loss: 0.6812, Train Acc: 0.5587 | Val Loss: 0.6881, Val Acc: 0.5300
# Epoch [11/350] | Train Loss: 0.6742, Train Acc: 0.5587 | Val Loss: 0.7072, Val Acc: 0.5500
# Epoch [12/350] | Train Loss: 0.6743, Train Acc: 0.5900 | Val Loss: 0.6960, Val Acc: 0.5050
# Epoch [13/350] | Train Loss: 0.6662, Train Acc: 0.6038 | Val Loss: 0.6926, Val Acc: 0.5200
# Epoch [14/350] | Train Loss: 0.6617, Train Acc: 0.6188 | Val Loss: 0.6961, Val Acc: 0.5150
# Epoch [15/350] | Train Loss: 0.6610, Train Acc: 0.6425 | Val Loss: 0.6864, Val Acc: 0.5600
# Epoch [16/350] | Train Loss: 0.6596, Train Acc: 0.6462 | Val Loss: 0.6923, Val Acc: 0.5300
# Epoch [17/350] | Train Loss: 0.6582, Train Acc: 0.6625 | Val Loss: 0.6878, Val Acc: 0.5300
# Epoch [18/350] | Train Loss: 0.6575, Train Acc: 0.6350 | Val Loss: 0.6989, Val Acc: 0.4950
# Epoch [19/350] | Train Loss: 0.6552, Train Acc: 0.6600 | Val Loss: 0.6880, Val Acc: 0.5500
# Epoch [20/350] | Train Loss: 0.6549, Train Acc: 0.6625 | Val Loss: 0.6847, Val Acc: 0.5550
# Epoch [21/350] | Train Loss: 0.6536, Train Acc: 0.6700 | Val Loss: 0.6901, Val Acc: 0.5300
# Epoch [22/350] | Train Loss: 0.6531, Train Acc: 0.6525 | Val Loss: 0.6863, Val Acc: 0.5350
# Epoch [23/350] | Train Loss: 0.6522, Train Acc: 0.6675 | Val Loss: 0.6897, Val Acc: 0.5250
# Epoch [24/350] | Train Loss: 0.6517, Train Acc: 0.6700 | Val Loss: 0.6882, Val Acc: 0.5350
# Epoch [25/350] | Train Loss: 0.6515, Train Acc: 0.6775 | Val Loss: 0.6866, Val Acc: 0.5600
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=RMSProp, epochs=5
# Epoch [1/5] | Train Loss: 0.7189, Train Acc: 0.5200 | Val Loss: 0.6631, Val Acc: 0.6300
# Epoch [2/5] | Train Loss: 0.5767, Train Acc: 0.7638 | Val Loss: 0.6517, Val Acc: 0.5950
# Epoch [3/5] | Train Loss: 0.4843, Train Acc: 0.8650 | Val Loss: 0.6116, Val Acc: 0.6700
# Epoch [4/5] | Train Loss: 0.3881, Train Acc: 0.9038 | Val Loss: 0.5793, Val Acc: 0.6950
# Epoch [5/5] | Train Loss: 0.2908, Train Acc: 0.9500 | Val Loss: 0.5646, Val Acc: 0.6900
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=RMSProp, epochs=50
# Epoch [1/50] | Train Loss: 0.7136, Train Acc: 0.5475 | Val Loss: 0.6614, Val Acc: 0.6200
# Epoch [2/50] | Train Loss: 0.5996, Train Acc: 0.7212 | Val Loss: 0.6411, Val Acc: 0.6300
# Epoch [3/50] | Train Loss: 0.5011, Train Acc: 0.8400 | Val Loss: 0.6009, Val Acc: 0.7000
# Epoch [4/50] | Train Loss: 0.4114, Train Acc: 0.8725 | Val Loss: 0.5887, Val Acc: 0.7000
# Epoch [5/50] | Train Loss: 0.3221, Train Acc: 0.9113 | Val Loss: 0.5812, Val Acc: 0.6800
# Epoch [6/50] | Train Loss: 0.2374, Train Acc: 0.9600 | Val Loss: 0.5853, Val Acc: 0.6900
# Epoch [7/50] | Train Loss: 0.1737, Train Acc: 0.9812 | Val Loss: 0.5793, Val Acc: 0.6850
# Epoch [8/50] | Train Loss: 0.1279, Train Acc: 0.9788 | Val Loss: 0.5736, Val Acc: 0.7150
# Epoch [9/50] | Train Loss: 0.0879, Train Acc: 0.9925 | Val Loss: 0.5714, Val Acc: 0.7300
# Epoch [10/50] | Train Loss: 0.0650, Train Acc: 0.9950 | Val Loss: 0.5823, Val Acc: 0.7350
# Epoch [11/50] | Train Loss: 0.0476, Train Acc: 0.9975 | Val Loss: 0.5811, Val Acc: 0.7450
# Epoch [12/50] | Train Loss: 0.0345, Train Acc: 0.9975 | Val Loss: 0.6148, Val Acc: 0.7550
# Epoch [13/50] | Train Loss: 0.0236, Train Acc: 0.9975 | Val Loss: 0.5999, Val Acc: 0.7550
# Epoch [14/50] | Train Loss: 0.0199, Train Acc: 0.9975 | Val Loss: 0.6096, Val Acc: 0.7500
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=RMSProp, epochs=100
# Epoch [1/100] | Train Loss: 0.7137, Train Acc: 0.5250 | Val Loss: 0.6602, Val Acc: 0.6000
# Epoch [2/100] | Train Loss: 0.5814, Train Acc: 0.7500 | Val Loss: 0.6512, Val Acc: 0.6250
# Epoch [3/100] | Train Loss: 0.4974, Train Acc: 0.8325 | Val Loss: 0.6284, Val Acc: 0.6150
# Epoch [4/100] | Train Loss: 0.3973, Train Acc: 0.8912 | Val Loss: 0.6198, Val Acc: 0.6650
# Epoch [5/100] | Train Loss: 0.2950, Train Acc: 0.9387 | Val Loss: 0.5999, Val Acc: 0.6850
# Epoch [6/100] | Train Loss: 0.2248, Train Acc: 0.9600 | Val Loss: 0.6168, Val Acc: 0.6700
# Epoch [7/100] | Train Loss: 0.1680, Train Acc: 0.9812 | Val Loss: 0.6460, Val Acc: 0.6800
# Epoch [8/100] | Train Loss: 0.1231, Train Acc: 0.9850 | Val Loss: 0.6215, Val Acc: 0.6800
# Epoch [9/100] | Train Loss: 0.0812, Train Acc: 0.9950 | Val Loss: 0.6111, Val Acc: 0.7150
# Epoch [10/100] | Train Loss: 0.0666, Train Acc: 0.9950 | Val Loss: 0.6237, Val Acc: 0.7000
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=RMSProp, epochs=250
# Epoch [1/250] | Train Loss: 0.7198, Train Acc: 0.5188 | Val Loss: 0.6629, Val Acc: 0.6250
# Epoch [2/250] | Train Loss: 0.5797, Train Acc: 0.7450 | Val Loss: 0.6449, Val Acc: 0.6200
# Epoch [3/250] | Train Loss: 0.4924, Train Acc: 0.8300 | Val Loss: 0.6170, Val Acc: 0.6500
# Epoch [4/250] | Train Loss: 0.3900, Train Acc: 0.9075 | Val Loss: 0.6014, Val Acc: 0.6750
# Epoch [5/250] | Train Loss: 0.2971, Train Acc: 0.9400 | Val Loss: 0.5948, Val Acc: 0.6800
# Epoch [6/250] | Train Loss: 0.2125, Train Acc: 0.9688 | Val Loss: 0.5983, Val Acc: 0.7050
# Epoch [7/250] | Train Loss: 0.1649, Train Acc: 0.9788 | Val Loss: 0.6060, Val Acc: 0.6900
# Epoch [8/250] | Train Loss: 0.1083, Train Acc: 0.9912 | Val Loss: 0.6135, Val Acc: 0.7200
# Epoch [9/250] | Train Loss: 0.0727, Train Acc: 0.9938 | Val Loss: 0.6330, Val Acc: 0.7250
# Epoch [10/250] | Train Loss: 0.0608, Train Acc: 0.9950 | Val Loss: 0.6436, Val Acc: 0.7000
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=RMSProp, epochs=350
# Epoch [1/350] | Train Loss: 0.7127, Train Acc: 0.5463 | Val Loss: 0.6600, Val Acc: 0.6400
# Epoch [2/350] | Train Loss: 0.5802, Train Acc: 0.7450 | Val Loss: 0.6346, Val Acc: 0.6450
# Epoch [3/350] | Train Loss: 0.4938, Train Acc: 0.8187 | Val Loss: 0.6126, Val Acc: 0.6450
# Epoch [4/350] | Train Loss: 0.3940, Train Acc: 0.8862 | Val Loss: 0.6091, Val Acc: 0.6850
# Epoch [5/350] | Train Loss: 0.2954, Train Acc: 0.9125 | Val Loss: 0.6103, Val Acc: 0.6750
# Epoch [6/350] | Train Loss: 0.2191, Train Acc: 0.9650 | Val Loss: 0.5959, Val Acc: 0.6900
# Epoch [7/350] | Train Loss: 0.1625, Train Acc: 0.9725 | Val Loss: 0.6184, Val Acc: 0.6850
# Epoch [8/350] | Train Loss: 0.1151, Train Acc: 0.9862 | Val Loss: 0.6228, Val Acc: 0.7050
# Epoch [9/350] | Train Loss: 0.0809, Train Acc: 0.9938 | Val Loss: 0.6280, Val Acc: 0.6950
# Epoch [10/350] | Train Loss: 0.0528, Train Acc: 0.9975 | Val Loss: 0.6525, Val Acc: 0.6950
# Epoch [11/350] | Train Loss: 0.0457, Train Acc: 0.9962 | Val Loss: 0.6760, Val Acc: 0.7050
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=Adam, epochs=5
# Epoch [1/5] | Train Loss: 0.6910, Train Acc: 0.5288 | Val Loss: 0.6905, Val Acc: 0.5250
# Epoch [2/5] | Train Loss: 0.6360, Train Acc: 0.6400 | Val Loss: 0.6733, Val Acc: 0.5850
# Epoch [3/5] | Train Loss: 0.5897, Train Acc: 0.8475 | Val Loss: 0.6656, Val Acc: 0.5850
# Epoch [4/5] | Train Loss: 0.5381, Train Acc: 0.8838 | Val Loss: 0.6524, Val Acc: 0.6100
# Epoch [5/5] | Train Loss: 0.4734, Train Acc: 0.8888 | Val Loss: 0.6552, Val Acc: 0.5850
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=Adam, epochs=50
# Epoch [1/50] | Train Loss: 0.7015, Train Acc: 0.5100 | Val Loss: 0.6756, Val Acc: 0.6000
# Epoch [2/50] | Train Loss: 0.6387, Train Acc: 0.6525 | Val Loss: 0.6643, Val Acc: 0.6200
# Epoch [3/50] | Train Loss: 0.5898, Train Acc: 0.8387 | Val Loss: 0.6583, Val Acc: 0.6150
# Epoch [4/50] | Train Loss: 0.5420, Train Acc: 0.8888 | Val Loss: 0.6440, Val Acc: 0.6200
# Epoch [5/50] | Train Loss: 0.4814, Train Acc: 0.8600 | Val Loss: 0.6358, Val Acc: 0.6200
# Epoch [6/50] | Train Loss: 0.4060, Train Acc: 0.9125 | Val Loss: 0.6559, Val Acc: 0.6150
# Epoch [7/50] | Train Loss: 0.3250, Train Acc: 0.9225 | Val Loss: 0.6403, Val Acc: 0.6550
# Epoch [8/50] | Train Loss: 0.2431, Train Acc: 0.9525 | Val Loss: 0.6496, Val Acc: 0.6650
# Epoch [9/50] | Train Loss: 0.1774, Train Acc: 0.9712 | Val Loss: 0.6974, Val Acc: 0.6700
# Epoch [10/50] | Train Loss: 0.1391, Train Acc: 0.9750 | Val Loss: 0.7338, Val Acc: 0.6700
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=Adam, epochs=100
# Epoch [1/100] | Train Loss: 0.6983, Train Acc: 0.5200 | Val Loss: 0.6825, Val Acc: 0.5300
# Epoch [2/100] | Train Loss: 0.6369, Train Acc: 0.6587 | Val Loss: 0.6827, Val Acc: 0.5350
# Epoch [3/100] | Train Loss: 0.5901, Train Acc: 0.7812 | Val Loss: 0.6437, Val Acc: 0.5950
# Epoch [4/100] | Train Loss: 0.5398, Train Acc: 0.8425 | Val Loss: 0.6258, Val Acc: 0.6150
# Epoch [5/100] | Train Loss: 0.4758, Train Acc: 0.9038 | Val Loss: 0.6069, Val Acc: 0.6850
# Epoch [6/100] | Train Loss: 0.4055, Train Acc: 0.9125 | Val Loss: 0.6133, Val Acc: 0.6700
# Epoch [7/100] | Train Loss: 0.3170, Train Acc: 0.9550 | Val Loss: 0.5955, Val Acc: 0.6950
# Epoch [8/100] | Train Loss: 0.2465, Train Acc: 0.9613 | Val Loss: 0.6121, Val Acc: 0.6850
# Epoch [9/100] | Train Loss: 0.1747, Train Acc: 0.9788 | Val Loss: 0.6286, Val Acc: 0.6650
# Epoch [10/100] | Train Loss: 0.1265, Train Acc: 0.9938 | Val Loss: 0.6372, Val Acc: 0.6800
# Epoch [11/100] | Train Loss: 0.0870, Train Acc: 0.9975 | Val Loss: 0.6598, Val Acc: 0.6700
# Epoch [12/100] | Train Loss: 0.0722, Train Acc: 0.9975 | Val Loss: 0.6892, Val Acc: 0.6900
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=Adam, epochs=250
# Epoch [1/250] | Train Loss: 0.6932, Train Acc: 0.5262 | Val Loss: 0.6785, Val Acc: 0.5450
# Epoch [2/250] | Train Loss: 0.6383, Train Acc: 0.7200 | Val Loss: 0.6672, Val Acc: 0.6000
# Epoch [3/250] | Train Loss: 0.5968, Train Acc: 0.8087 | Val Loss: 0.6529, Val Acc: 0.6400
# Epoch [4/250] | Train Loss: 0.5470, Train Acc: 0.8550 | Val Loss: 0.6358, Val Acc: 0.6350
# Epoch [5/250] | Train Loss: 0.4817, Train Acc: 0.8700 | Val Loss: 0.6480, Val Acc: 0.6050
# Epoch [6/250] | Train Loss: 0.4105, Train Acc: 0.9113 | Val Loss: 0.6183, Val Acc: 0.6600
# Epoch [7/250] | Train Loss: 0.3231, Train Acc: 0.9350 | Val Loss: 0.6672, Val Acc: 0.6100
# Epoch [8/250] | Train Loss: 0.2412, Train Acc: 0.9725 | Val Loss: 0.6330, Val Acc: 0.6650
# Epoch [9/250] | Train Loss: 0.1761, Train Acc: 0.9862 | Val Loss: 0.7068, Val Acc: 0.6400
# Epoch [10/250] | Train Loss: 0.1275, Train Acc: 0.9938 | Val Loss: 0.6731, Val Acc: 0.6500
# Epoch [11/250] | Train Loss: 0.1005, Train Acc: 0.9950 | Val Loss: 0.7016, Val Acc: 0.6650
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=max, optimizer=Adam, epochs=350
# Epoch [1/350] | Train Loss: 0.6961, Train Acc: 0.4888 | Val Loss: 0.6860, Val Acc: 0.5250
# Epoch [2/350] | Train Loss: 0.6392, Train Acc: 0.7063 | Val Loss: 0.6817, Val Acc: 0.5350
# Epoch [3/350] | Train Loss: 0.5999, Train Acc: 0.7825 | Val Loss: 0.6687, Val Acc: 0.5600
# Epoch [4/350] | Train Loss: 0.5518, Train Acc: 0.8325 | Val Loss: 0.6467, Val Acc: 0.6100
# Epoch [5/350] | Train Loss: 0.4885, Train Acc: 0.9000 | Val Loss: 0.6336, Val Acc: 0.6400
# Epoch [6/350] | Train Loss: 0.4068, Train Acc: 0.9087 | Val Loss: 0.6253, Val Acc: 0.6600
# Epoch [7/350] | Train Loss: 0.3154, Train Acc: 0.9325 | Val Loss: 0.6937, Val Acc: 0.6100
# Epoch [8/350] | Train Loss: 0.2457, Train Acc: 0.9525 | Val Loss: 0.6359, Val Acc: 0.6600
# Epoch [9/350] | Train Loss: 0.1890, Train Acc: 0.9775 | Val Loss: 0.6371, Val Acc: 0.6950
# Epoch [10/350] | Train Loss: 0.1345, Train Acc: 0.9900 | Val Loss: 0.6465, Val Acc: 0.6800
# Epoch [11/350] | Train Loss: 0.1119, Train Acc: 0.9925 | Val Loss: 0.6601, Val Acc: 0.6800
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=SGD, epochs=5
# Epoch [1/5] | Train Loss: 0.6970, Train Acc: 0.4825 | Val Loss: 0.6905, Val Acc: 0.5700
# Epoch [2/5] | Train Loss: 0.6950, Train Acc: 0.4562 | Val Loss: 0.6917, Val Acc: 0.5050
# Epoch [3/5] | Train Loss: 0.6942, Train Acc: 0.4913 | Val Loss: 0.6929, Val Acc: 0.5000
# Epoch [4/5] | Train Loss: 0.6937, Train Acc: 0.4850 | Val Loss: 0.6938, Val Acc: 0.4750
# Epoch [5/5] | Train Loss: 0.6931, Train Acc: 0.5162 | Val Loss: 0.6941, Val Acc: 0.4650
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=SGD, epochs=50
# Epoch [1/50] | Train Loss: 0.7022, Train Acc: 0.4875 | Val Loss: 0.6908, Val Acc: 0.5350
# Epoch [2/50] | Train Loss: 0.6970, Train Acc: 0.4875 | Val Loss: 0.6922, Val Acc: 0.5550
# Epoch [3/50] | Train Loss: 0.6948, Train Acc: 0.4738 | Val Loss: 0.6934, Val Acc: 0.5450
# Epoch [4/50] | Train Loss: 0.6939, Train Acc: 0.5000 | Val Loss: 0.6946, Val Acc: 0.4700
# Epoch [5/50] | Train Loss: 0.6931, Train Acc: 0.5138 | Val Loss: 0.6950, Val Acc: 0.4450
# Epoch [6/50] | Train Loss: 0.6929, Train Acc: 0.5200 | Val Loss: 0.6954, Val Acc: 0.4300
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=SGD, epochs=100
# Epoch [1/100] | Train Loss: 0.6909, Train Acc: 0.5175 | Val Loss: 0.6917, Val Acc: 0.5350
# Epoch [2/100] | Train Loss: 0.6904, Train Acc: 0.5475 | Val Loss: 0.6924, Val Acc: 0.5050
# Epoch [3/100] | Train Loss: 0.6900, Train Acc: 0.5500 | Val Loss: 0.6923, Val Acc: 0.5000
# Epoch [4/100] | Train Loss: 0.6896, Train Acc: 0.5463 | Val Loss: 0.6925, Val Acc: 0.4900
# Epoch [5/100] | Train Loss: 0.6892, Train Acc: 0.5525 | Val Loss: 0.6927, Val Acc: 0.5000
# Epoch [6/100] | Train Loss: 0.6890, Train Acc: 0.5563 | Val Loss: 0.6928, Val Acc: 0.4800
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=SGD, epochs=250
# Epoch [1/250] | Train Loss: 0.6946, Train Acc: 0.5112 | Val Loss: 0.6971, Val Acc: 0.4650
# Epoch [2/250] | Train Loss: 0.6942, Train Acc: 0.5062 | Val Loss: 0.6965, Val Acc: 0.4650
# Epoch [3/250] | Train Loss: 0.6939, Train Acc: 0.5038 | Val Loss: 0.6960, Val Acc: 0.4600
# Epoch [4/250] | Train Loss: 0.6937, Train Acc: 0.5125 | Val Loss: 0.6960, Val Acc: 0.4600
# Epoch [5/250] | Train Loss: 0.6935, Train Acc: 0.5088 | Val Loss: 0.6959, Val Acc: 0.4650
# Epoch [6/250] | Train Loss: 0.6931, Train Acc: 0.5050 | Val Loss: 0.6955, Val Acc: 0.4700
# Epoch [7/250] | Train Loss: 0.6928, Train Acc: 0.5088 | Val Loss: 0.6954, Val Acc: 0.4700
# Epoch [8/250] | Train Loss: 0.6925, Train Acc: 0.5075 | Val Loss: 0.6951, Val Acc: 0.4700
# Epoch [9/250] | Train Loss: 0.6923, Train Acc: 0.5075 | Val Loss: 0.6952, Val Acc: 0.4700
# Epoch [10/250] | Train Loss: 0.6922, Train Acc: 0.5162 | Val Loss: 0.6952, Val Acc: 0.4700
# Epoch [11/250] | Train Loss: 0.6919, Train Acc: 0.5138 | Val Loss: 0.6954, Val Acc: 0.4700
# Epoch [12/250] | Train Loss: 0.6914, Train Acc: 0.5088 | Val Loss: 0.6953, Val Acc: 0.4700
# Epoch [13/250] | Train Loss: 0.6914, Train Acc: 0.5162 | Val Loss: 0.6952, Val Acc: 0.4700
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=SGD, epochs=350
# Epoch [1/350] | Train Loss: 0.6943, Train Acc: 0.4950 | Val Loss: 0.6962, Val Acc: 0.4600
# Epoch [2/350] | Train Loss: 0.6938, Train Acc: 0.5000 | Val Loss: 0.6967, Val Acc: 0.4750
# Epoch [3/350] | Train Loss: 0.6937, Train Acc: 0.5025 | Val Loss: 0.6968, Val Acc: 0.4700
# Epoch [4/350] | Train Loss: 0.6934, Train Acc: 0.5038 | Val Loss: 0.6971, Val Acc: 0.4600
# Epoch [5/350] | Train Loss: 0.6931, Train Acc: 0.5038 | Val Loss: 0.6971, Val Acc: 0.4600
# Epoch [6/350] | Train Loss: 0.6929, Train Acc: 0.5038 | Val Loss: 0.6971, Val Acc: 0.4600
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=RMSProp, epochs=5
# Epoch [1/5] | Train Loss: 0.6915, Train Acc: 0.5675 | Val Loss: 0.6783, Val Acc: 0.5850
# Epoch [2/5] | Train Loss: 0.6367, Train Acc: 0.6975 | Val Loss: 0.6663, Val Acc: 0.6450
# Epoch [3/5] | Train Loss: 0.5140, Train Acc: 0.7712 | Val Loss: 1.1054, Val Acc: 0.5000
# Epoch [4/5] | Train Loss: 0.4470, Train Acc: 0.7937 | Val Loss: 0.6199, Val Acc: 0.6700
# Epoch [5/5] | Train Loss: 0.3560, Train Acc: 0.8488 | Val Loss: 0.6531, Val Acc: 0.6750
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=RMSProp, epochs=50
# Epoch [1/50] | Train Loss: 0.7029, Train Acc: 0.5850 | Val Loss: 0.6754, Val Acc: 0.5750
# Epoch [2/50] | Train Loss: 0.5953, Train Acc: 0.7013 | Val Loss: 0.6797, Val Acc: 0.5900
# Epoch [3/50] | Train Loss: 0.5246, Train Acc: 0.7550 | Val Loss: 0.7392, Val Acc: 0.6100
# Epoch [4/50] | Train Loss: 0.4473, Train Acc: 0.8050 | Val Loss: 0.7269, Val Acc: 0.6000
# Epoch [5/50] | Train Loss: 0.3815, Train Acc: 0.8438 | Val Loss: 0.7810, Val Acc: 0.5950
# Epoch [6/50] | Train Loss: 0.3427, Train Acc: 0.8625 | Val Loss: 0.7694, Val Acc: 0.6300
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=RMSProp, epochs=100
# Epoch [1/100] | Train Loss: 0.6881, Train Acc: 0.5475 | Val Loss: 0.6813, Val Acc: 0.5450
# Epoch [2/100] | Train Loss: 0.6176, Train Acc: 0.6763 | Val Loss: 0.6577, Val Acc: 0.6450
# Epoch [3/100] | Train Loss: 0.5421, Train Acc: 0.7475 | Val Loss: 0.6757, Val Acc: 0.5900
# Epoch [4/100] | Train Loss: 0.4105, Train Acc: 0.8163 | Val Loss: 0.6872, Val Acc: 0.6600
# Epoch [5/100] | Train Loss: 0.3470, Train Acc: 0.8500 | Val Loss: 0.7180, Val Acc: 0.6400
# Epoch [6/100] | Train Loss: 0.3051, Train Acc: 0.8762 | Val Loss: 0.6227, Val Acc: 0.6650
# Epoch [7/100] | Train Loss: 0.2780, Train Acc: 0.9025 | Val Loss: 0.7127, Val Acc: 0.6700
# Epoch [8/100] | Train Loss: 0.2523, Train Acc: 0.8975 | Val Loss: 0.7871, Val Acc: 0.6550
# Epoch [9/100] | Train Loss: 0.2354, Train Acc: 0.9087 | Val Loss: 0.7505, Val Acc: 0.6700
# Epoch [10/100] | Train Loss: 0.2081, Train Acc: 0.9263 | Val Loss: 0.7683, Val Acc: 0.6650
# Epoch [11/100] | Train Loss: 0.1987, Train Acc: 0.9287 | Val Loss: 0.7636, Val Acc: 0.6700
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=RMSProp, epochs=250
# Epoch [1/250] | Train Loss: 0.6768, Train Acc: 0.5863 | Val Loss: 0.7100, Val Acc: 0.4950
# Epoch [2/250] | Train Loss: 0.6048, Train Acc: 0.6887 | Val Loss: 0.6531, Val Acc: 0.6600
# Epoch [3/250] | Train Loss: 0.4707, Train Acc: 0.7812 | Val Loss: 0.6699, Val Acc: 0.6850
# Epoch [4/250] | Train Loss: 0.3804, Train Acc: 0.8350 | Val Loss: 0.6132, Val Acc: 0.7100
# Epoch [5/250] | Train Loss: 0.3456, Train Acc: 0.8638 | Val Loss: 0.6195, Val Acc: 0.7250
# Epoch [6/250] | Train Loss: 0.2929, Train Acc: 0.8912 | Val Loss: 0.7451, Val Acc: 0.7200
# Epoch [7/250] | Train Loss: 0.2525, Train Acc: 0.9075 | Val Loss: 0.6523, Val Acc: 0.7250
# Epoch [8/250] | Train Loss: 0.2212, Train Acc: 0.9263 | Val Loss: 0.7008, Val Acc: 0.7100
# Epoch [9/250] | Train Loss: 0.1996, Train Acc: 0.9350 | Val Loss: 0.7400, Val Acc: 0.7200
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=RMSProp, epochs=350
# Epoch [1/350] | Train Loss: 0.6887, Train Acc: 0.5375 | Val Loss: 0.6773, Val Acc: 0.5950
# Epoch [2/350] | Train Loss: 0.6183, Train Acc: 0.6750 | Val Loss: 0.6475, Val Acc: 0.6450
# Epoch [3/350] | Train Loss: 0.5762, Train Acc: 0.7412 | Val Loss: 0.6083, Val Acc: 0.6750
# Epoch [4/350] | Train Loss: 0.4300, Train Acc: 0.8137 | Val Loss: 0.6673, Val Acc: 0.6500
# Epoch [5/350] | Train Loss: 0.4294, Train Acc: 0.8025 | Val Loss: 0.6430, Val Acc: 0.6700
# Epoch [6/350] | Train Loss: 0.3453, Train Acc: 0.8538 | Val Loss: 0.6128, Val Acc: 0.6800
# Epoch [7/350] | Train Loss: 0.2972, Train Acc: 0.8800 | Val Loss: 0.6485, Val Acc: 0.6550
# Epoch [8/350] | Train Loss: 0.2736, Train Acc: 0.8962 | Val Loss: 0.6647, Val Acc: 0.6600
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=Adam, epochs=5
# Epoch [1/5] | Train Loss: 0.6893, Train Acc: 0.5387 | Val Loss: 0.6870, Val Acc: 0.5850
# Epoch [2/5] | Train Loss: 0.6646, Train Acc: 0.6288 | Val Loss: 0.6894, Val Acc: 0.5000
# Epoch [3/5] | Train Loss: 0.6221, Train Acc: 0.6737 | Val Loss: 0.6392, Val Acc: 0.6400
# Epoch [4/5] | Train Loss: 0.5355, Train Acc: 0.7262 | Val Loss: 0.6618, Val Acc: 0.5700
# Epoch [5/5] | Train Loss: 0.4593, Train Acc: 0.7950 | Val Loss: 0.6462, Val Acc: 0.6400
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=Adam, epochs=50
# Epoch [1/50] | Train Loss: 0.6889, Train Acc: 0.5463 | Val Loss: 0.7083, Val Acc: 0.4650
# Epoch [2/50] | Train Loss: 0.6702, Train Acc: 0.6200 | Val Loss: 0.6824, Val Acc: 0.5200
# Epoch [3/50] | Train Loss: 0.6216, Train Acc: 0.6663 | Val Loss: 0.6620, Val Acc: 0.6100
# Epoch [4/50] | Train Loss: 0.5475, Train Acc: 0.7350 | Val Loss: 0.6416, Val Acc: 0.6500
# Epoch [5/50] | Train Loss: 0.4940, Train Acc: 0.7812 | Val Loss: 0.6432, Val Acc: 0.6900
# Epoch [6/50] | Train Loss: 0.4535, Train Acc: 0.7963 | Val Loss: 0.6398, Val Acc: 0.6950
# Epoch [7/50] | Train Loss: 0.3871, Train Acc: 0.8475 | Val Loss: 0.6206, Val Acc: 0.6950
# Epoch [8/50] | Train Loss: 0.3397, Train Acc: 0.8575 | Val Loss: 0.7660, Val Acc: 0.6700
# Epoch [9/50] | Train Loss: 0.3529, Train Acc: 0.8638 | Val Loss: 0.6418, Val Acc: 0.6950
# Epoch [10/50] | Train Loss: 0.2569, Train Acc: 0.8950 | Val Loss: 0.6733, Val Acc: 0.7050
# Epoch [11/50] | Train Loss: 0.2165, Train Acc: 0.9213 | Val Loss: 0.6650, Val Acc: 0.7000
# Epoch [12/50] | Train Loss: 0.1978, Train Acc: 0.9325 | Val Loss: 0.6844, Val Acc: 0.7050
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=Adam, epochs=100
# Epoch [1/100] | Train Loss: 0.6887, Train Acc: 0.5587 | Val Loss: 0.6864, Val Acc: 0.5900
# Epoch [2/100] | Train Loss: 0.6666, Train Acc: 0.6250 | Val Loss: 0.6841, Val Acc: 0.5500
# Epoch [3/100] | Train Loss: 0.6272, Train Acc: 0.6488 | Val Loss: 0.6664, Val Acc: 0.6050
# Epoch [4/100] | Train Loss: 0.5659, Train Acc: 0.7175 | Val Loss: 0.6697, Val Acc: 0.6450
# Epoch [5/100] | Train Loss: 0.4748, Train Acc: 0.7875 | Val Loss: 0.6057, Val Acc: 0.6900
# Epoch [6/100] | Train Loss: 0.3850, Train Acc: 0.8363 | Val Loss: 0.6718, Val Acc: 0.6850
# Epoch [7/100] | Train Loss: 0.3555, Train Acc: 0.8500 | Val Loss: 0.6739, Val Acc: 0.6850
# Epoch [8/100] | Train Loss: 0.3162, Train Acc: 0.8762 | Val Loss: 0.6154, Val Acc: 0.7000
# Epoch [9/100] | Train Loss: 0.2698, Train Acc: 0.8938 | Val Loss: 0.5903, Val Acc: 0.7250
# Epoch [10/100] | Train Loss: 0.2336, Train Acc: 0.9137 | Val Loss: 0.6143, Val Acc: 0.7250
# Epoch [11/100] | Train Loss: 0.2028, Train Acc: 0.9237 | Val Loss: 0.6461, Val Acc: 0.7250
# Epoch [12/100] | Train Loss: 0.1797, Train Acc: 0.9337 | Val Loss: 0.6587, Val Acc: 0.7150
# Epoch [13/100] | Train Loss: 0.1611, Train Acc: 0.9437 | Val Loss: 0.6715, Val Acc: 0.7150
# Epoch [14/100] | Train Loss: 0.1581, Train Acc: 0.9437 | Val Loss: 0.6638, Val Acc: 0.7250
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=Adam, epochs=250
# Epoch [1/250] | Train Loss: 0.6901, Train Acc: 0.5288 | Val Loss: 0.7103, Val Acc: 0.4600
# Epoch [2/250] | Train Loss: 0.6640, Train Acc: 0.6250 | Val Loss: 0.6816, Val Acc: 0.5750
# Epoch [3/250] | Train Loss: 0.6112, Train Acc: 0.6663 | Val Loss: 0.7099, Val Acc: 0.5100
# Epoch [4/250] | Train Loss: 0.5356, Train Acc: 0.7638 | Val Loss: 0.6877, Val Acc: 0.6150
# Epoch [5/250] | Train Loss: 0.4434, Train Acc: 0.8050 | Val Loss: 0.7968, Val Acc: 0.6250
# Epoch [6/250] | Train Loss: 0.4047, Train Acc: 0.8275 | Val Loss: 0.7623, Val Acc: 0.6300
# Epoch [7/250] | Train Loss: 0.3868, Train Acc: 0.8512 | Val Loss: 0.7607, Val Acc: 0.6250
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=64, pooling=avg, optimizer=Adam, epochs=350
# Epoch [1/350] | Train Loss: 0.6906, Train Acc: 0.5513 | Val Loss: 0.6984, Val Acc: 0.4750
# Epoch [2/350] | Train Loss: 0.6681, Train Acc: 0.6212 | Val Loss: 0.6835, Val Acc: 0.5200
# Epoch [3/350] | Train Loss: 0.6260, Train Acc: 0.6813 | Val Loss: 0.6962, Val Acc: 0.5550
# Epoch [4/350] | Train Loss: 0.5611, Train Acc: 0.7500 | Val Loss: 0.7285, Val Acc: 0.6000
# Epoch [5/350] | Train Loss: 0.4790, Train Acc: 0.7850 | Val Loss: 0.6853, Val Acc: 0.6700
# Epoch [6/350] | Train Loss: 0.3975, Train Acc: 0.8337 | Val Loss: 0.7139, Val Acc: 0.6600
# Epoch [7/350] | Train Loss: 0.3663, Train Acc: 0.8512 | Val Loss: 0.7286, Val Acc: 0.6600
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=max, optimizer=SGD, epochs=5
# Epoch [1/5] | Train Loss: 0.7015, Train Acc: 0.4850 | Val Loss: 0.6931, Val Acc: 0.5400
# Epoch [2/5] | Train Loss: 0.6945, Train Acc: 0.5337 | Val Loss: 0.7049, Val Acc: 0.4550
# Epoch [3/5] | Train Loss: 0.6934, Train Acc: 0.5513 | Val Loss: 0.6942, Val Acc: 0.5450
# Epoch [4/5] | Train Loss: 0.6891, Train Acc: 0.5450 | Val Loss: 0.6891, Val Acc: 0.5400
# Epoch [5/5] | Train Loss: 0.6767, Train Acc: 0.5637 | Val Loss: 0.7478, Val Acc: 0.4650
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=max, optimizer=SGD, epochs=50
# Epoch [1/50] | Train Loss: 0.7142, Train Acc: 0.4888 | Val Loss: 0.6809, Val Acc: 0.5550
# Epoch [2/50] | Train Loss: 0.6986, Train Acc: 0.5200 | Val Loss: 0.6834, Val Acc: 0.5600
# Epoch [3/50] | Train Loss: 0.6885, Train Acc: 0.5637 | Val Loss: 0.6782, Val Acc: 0.5800
# Epoch [4/50] | Train Loss: 0.6816, Train Acc: 0.5425 | Val Loss: 0.7169, Val Acc: 0.4700
# Epoch [5/50] | Train Loss: 0.6795, Train Acc: 0.5687 | Val Loss: 0.6764, Val Acc: 0.5600
# Epoch [6/50] | Train Loss: 0.6776, Train Acc: 0.5813 | Val Loss: 0.6783, Val Acc: 0.5500
# Epoch [7/50] | Train Loss: 0.6772, Train Acc: 0.5725 | Val Loss: 0.6748, Val Acc: 0.5950
# Epoch [8/50] | Train Loss: 0.6635, Train Acc: 0.6138 | Val Loss: 0.7199, Val Acc: 0.4650
# Epoch [9/50] | Train Loss: 0.6660, Train Acc: 0.5787 | Val Loss: 0.7252, Val Acc: 0.4650
# Epoch [10/50] | Train Loss: 0.6641, Train Acc: 0.6000 | Val Loss: 0.6750, Val Acc: 0.6000
# Epoch [11/50] | Train Loss: 0.6496, Train Acc: 0.6538 | Val Loss: 0.6809, Val Acc: 0.5300
# Epoch [12/50] | Train Loss: 0.6434, Train Acc: 0.6637 | Val Loss: 0.6919, Val Acc: 0.5150
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=max, optimizer=SGD, epochs=100
# Epoch [1/100] | Train Loss: 0.7013, Train Acc: 0.4963 | Val Loss: 0.6974, Val Acc: 0.4500
# Epoch [2/100] | Train Loss: 0.7006, Train Acc: 0.5225 | Val Loss: 0.6930, Val Acc: 0.5250
# Epoch [3/100] | Train Loss: 0.6955, Train Acc: 0.5312 | Val Loss: 0.6943, Val Acc: 0.5400
# Epoch [4/100] | Train Loss: 0.6880, Train Acc: 0.5350 | Val Loss: 0.6903, Val Acc: 0.5250
# Epoch [5/100] | Train Loss: 0.6830, Train Acc: 0.5463 | Val Loss: 0.6920, Val Acc: 0.4800
# Epoch [6/100] | Train Loss: 0.6819, Train Acc: 0.5813 | Val Loss: 0.7080, Val Acc: 0.4900
# Epoch [7/100] | Train Loss: 0.6784, Train Acc: 0.5563 | Val Loss: 0.6959, Val Acc: 0.5000
# Epoch [8/100] | Train Loss: 0.6673, Train Acc: 0.6162 | Val Loss: 0.6851, Val Acc: 0.5350
# Epoch [9/100] | Train Loss: 0.6610, Train Acc: 0.6162 | Val Loss: 0.6852, Val Acc: 0.5200
# Epoch [10/100] | Train Loss: 0.6593, Train Acc: 0.6412 | Val Loss: 0.6904, Val Acc: 0.5100
# Epoch [11/100] | Train Loss: 0.6566, Train Acc: 0.6587 | Val Loss: 0.6852, Val Acc: 0.5100
# Epoch [12/100] | Train Loss: 0.6542, Train Acc: 0.6837 | Val Loss: 0.6842, Val Acc: 0.5300
# Epoch [13/100] | Train Loss: 0.6525, Train Acc: 0.6800 | Val Loss: 0.6902, Val Acc: 0.5200
# Epoch [14/100] | Train Loss: 0.6515, Train Acc: 0.6963 | Val Loss: 0.6845, Val Acc: 0.5000
# Epoch [15/100] | Train Loss: 0.6497, Train Acc: 0.6813 | Val Loss: 0.6857, Val Acc: 0.5050
# Epoch [16/100] | Train Loss: 0.6468, Train Acc: 0.7025 | Val Loss: 0.6807, Val Acc: 0.5500
# Epoch [17/100] | Train Loss: 0.6469, Train Acc: 0.6850 | Val Loss: 0.6852, Val Acc: 0.5100
# Epoch [18/100] | Train Loss: 0.6450, Train Acc: 0.6987 | Val Loss: 0.6798, Val Acc: 0.5600
# Epoch [19/100] | Train Loss: 0.6449, Train Acc: 0.6987 | Val Loss: 0.6835, Val Acc: 0.5050
# Epoch [20/100] | Train Loss: 0.6451, Train Acc: 0.7037 | Val Loss: 0.6821, Val Acc: 0.5450
# Epoch [21/100] | Train Loss: 0.6441, Train Acc: 0.7225 | Val Loss: 0.6806, Val Acc: 0.5550
# Epoch [22/100] | Train Loss: 0.6431, Train Acc: 0.7250 | Val Loss: 0.6806, Val Acc: 0.5500
# Epoch [23/100] | Train Loss: 0.6432, Train Acc: 0.7262 | Val Loss: 0.6808, Val Acc: 0.5400
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=max, optimizer=SGD, epochs=250
# Epoch [1/250] | Train Loss: 0.6976, Train Acc: 0.4925 | Val Loss: 0.6922, Val Acc: 0.5150
# Epoch [2/250] | Train Loss: 0.6992, Train Acc: 0.5088 | Val Loss: 0.7070, Val Acc: 0.4950
# Epoch [3/250] | Train Loss: 0.6965, Train Acc: 0.5175 | Val Loss: 0.6881, Val Acc: 0.5400
# Epoch [4/250] | Train Loss: 0.7057, Train Acc: 0.4800 | Val Loss: 0.6991, Val Acc: 0.4950
# Epoch [5/250] | Train Loss: 0.6831, Train Acc: 0.5575 | Val Loss: 0.6850, Val Acc: 0.5600
# Epoch [6/250] | Train Loss: 0.6792, Train Acc: 0.5725 | Val Loss: 0.6835, Val Acc: 0.5750
# Epoch [7/250] | Train Loss: 0.6775, Train Acc: 0.5775 | Val Loss: 0.7020, Val Acc: 0.5000
# Epoch [8/250] | Train Loss: 0.6688, Train Acc: 0.6250 | Val Loss: 0.7091, Val Acc: 0.4800
# Epoch [9/250] | Train Loss: 0.6611, Train Acc: 0.6050 | Val Loss: 0.7055, Val Acc: 0.4900
# Epoch [10/250] | Train Loss: 0.6573, Train Acc: 0.6450 | Val Loss: 0.6784, Val Acc: 0.6050
# Epoch [11/250] | Train Loss: 0.6537, Train Acc: 0.6462 | Val Loss: 0.6844, Val Acc: 0.5450
# Epoch [12/250] | Train Loss: 0.6515, Train Acc: 0.6837 | Val Loss: 0.6741, Val Acc: 0.5800
# Epoch [13/250] | Train Loss: 0.6482, Train Acc: 0.6587 | Val Loss: 0.6737, Val Acc: 0.5650
# Epoch [14/250] | Train Loss: 0.6471, Train Acc: 0.6450 | Val Loss: 0.6843, Val Acc: 0.5400
# Epoch [15/250] | Train Loss: 0.6444, Train Acc: 0.6763 | Val Loss: 0.6713, Val Acc: 0.5800
# Epoch [16/250] | Train Loss: 0.6452, Train Acc: 0.6713 | Val Loss: 0.6752, Val Acc: 0.5800
# Epoch [17/250] | Train Loss: 0.6409, Train Acc: 0.6950 | Val Loss: 0.6805, Val Acc: 0.5500
# Epoch [18/250] | Train Loss: 0.6360, Train Acc: 0.6875 | Val Loss: 0.6695, Val Acc: 0.6250
# Epoch [19/250] | Train Loss: 0.6346, Train Acc: 0.6975 | Val Loss: 0.6681, Val Acc: 0.6050
# Epoch [20/250] | Train Loss: 0.6335, Train Acc: 0.6763 | Val Loss: 0.6672, Val Acc: 0.5950
# Epoch [21/250] | Train Loss: 0.6274, Train Acc: 0.6987 | Val Loss: 0.6851, Val Acc: 0.5200
# Epoch [22/250] | Train Loss: 0.6249, Train Acc: 0.7388 | Val Loss: 0.6837, Val Acc: 0.5250
# Epoch [23/250] | Train Loss: 0.6252, Train Acc: 0.7200 | Val Loss: 0.6707, Val Acc: 0.5950
# Epoch [24/250] | Train Loss: 0.6204, Train Acc: 0.7462 | Val Loss: 0.6697, Val Acc: 0.5950
# Epoch [25/250] | Train Loss: 0.6172, Train Acc: 0.7550 | Val Loss: 0.6680, Val Acc: 0.6000
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=max, optimizer=SGD, epochs=350
# Epoch [1/350] | Train Loss: 0.7029, Train Acc: 0.5025 | Val Loss: 0.7065, Val Acc: 0.4750
# Epoch [2/350] | Train Loss: 0.6962, Train Acc: 0.5075 | Val Loss: 0.7013, Val Acc: 0.4700
# Epoch [3/350] | Train Loss: 0.6897, Train Acc: 0.5250 | Val Loss: 0.7131, Val Acc: 0.4900
# Epoch [4/350] | Train Loss: 0.6939, Train Acc: 0.5212 | Val Loss: 0.6964, Val Acc: 0.4800
# Epoch [5/350] | Train Loss: 0.6833, Train Acc: 0.5537 | Val Loss: 0.7276, Val Acc: 0.4650
# Epoch [6/350] | Train Loss: 0.6790, Train Acc: 0.5650 | Val Loss: 0.7500, Val Acc: 0.4550
# Epoch [7/350] | Train Loss: 0.6693, Train Acc: 0.6100 | Val Loss: 0.7164, Val Acc: 0.4800
# Epoch [8/350] | Train Loss: 0.6653, Train Acc: 0.6275 | Val Loss: 0.6934, Val Acc: 0.5300
# Epoch [9/350] | Train Loss: 0.6600, Train Acc: 0.6412 | Val Loss: 0.6906, Val Acc: 0.5150
# Epoch [10/350] | Train Loss: 0.6565, Train Acc: 0.6438 | Val Loss: 0.6875, Val Acc: 0.5150
# Epoch [11/350] | Train Loss: 0.6563, Train Acc: 0.6400 | Val Loss: 0.6868, Val Acc: 0.5050
# Epoch [12/350] | Train Loss: 0.6503, Train Acc: 0.6700 | Val Loss: 0.7039, Val Acc: 0.5100
# Epoch [13/350] | Train Loss: 0.6495, Train Acc: 0.6937 | Val Loss: 0.6878, Val Acc: 0.5300
# Epoch [14/350] | Train Loss: 0.6449, Train Acc: 0.6813 | Val Loss: 0.6958, Val Acc: 0.5400
# Epoch [15/350] | Train Loss: 0.6438, Train Acc: 0.7000 | Val Loss: 0.6913, Val Acc: 0.5350
# Epoch [16/350] | Train Loss: 0.6416, Train Acc: 0.7225 | Val Loss: 0.6936, Val Acc: 0.5400
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=max, optimizer=RMSProp, epochs=5
# Epoch [1/5] | Train Loss: 0.7615, Train Acc: 0.5387 | Val Loss: 0.6385, Val Acc: 0.6400
# Epoch [2/5] | Train Loss: 0.5151, Train Acc: 0.7987 | Val Loss: 0.6189, Val Acc: 0.6750
# Epoch [3/5] | Train Loss: 0.3888, Train Acc: 0.8925 | Val Loss: 0.6548, Val Acc: 0.6100
# Epoch [4/5] | Train Loss: 0.2747, Train Acc: 0.9425 | Val Loss: 0.5820, Val Acc: 0.7250
# Epoch [5/5] | Train Loss: 0.1950, Train Acc: 0.9738 | Val Loss: 0.5913, Val Acc: 0.7200
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=max, optimizer=RMSProp, epochs=50
# Epoch [1/50] | Train Loss: 0.7543, Train Acc: 0.5400 | Val Loss: 0.6476, Val Acc: 0.6050
# Epoch [2/50] | Train Loss: 0.4866, Train Acc: 0.8125 | Val Loss: 0.6661, Val Acc: 0.6000
# Epoch [3/50] | Train Loss: 0.3761, Train Acc: 0.8838 | Val Loss: 0.6164, Val Acc: 0.6600
# Epoch [4/50] | Train Loss: 0.2594, Train Acc: 0.9463 | Val Loss: 0.6004, Val Acc: 0.6750
# Epoch [5/50] | Train Loss: 0.1767, Train Acc: 0.9788 | Val Loss: 0.5965, Val Acc: 0.7300
# Epoch [6/50] | Train Loss: 0.1209, Train Acc: 0.9888 | Val Loss: 0.6000, Val Acc: 0.7400
# Epoch [7/50] | Train Loss: 0.0986, Train Acc: 0.9875 | Val Loss: 0.6053, Val Acc: 0.7400
# Epoch [8/50] | Train Loss: 0.0544, Train Acc: 0.9975 | Val Loss: 0.6299, Val Acc: 0.7300
# Epoch [9/50] | Train Loss: 0.0355, Train Acc: 0.9975 | Val Loss: 0.6532, Val Acc: 0.7300
# Epoch [10/50] | Train Loss: 0.0298, Train Acc: 0.9975 | Val Loss: 0.6502, Val Acc: 0.7450
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=max, optimizer=RMSProp, epochs=100
# Epoch [1/100] | Train Loss: 0.7352, Train Acc: 0.5750 | Val Loss: 0.6268, Val Acc: 0.6550
# Epoch [2/100] | Train Loss: 0.5020, Train Acc: 0.8050 | Val Loss: 0.6105, Val Acc: 0.6650
# Epoch [3/100] | Train Loss: 0.3868, Train Acc: 0.8638 | Val Loss: 0.5788, Val Acc: 0.6950
# Epoch [4/100] | Train Loss: 0.2541, Train Acc: 0.9600 | Val Loss: 0.5813, Val Acc: 0.6800
# Epoch [5/100] | Train Loss: 0.1951, Train Acc: 0.9563 | Val Loss: 0.6210, Val Acc: 0.6950
# Epoch [6/100] | Train Loss: 0.1211, Train Acc: 0.9938 | Val Loss: 0.5978, Val Acc: 0.6950
# Epoch [7/100] | Train Loss: 0.0735, Train Acc: 0.9975 | Val Loss: 0.6056, Val Acc: 0.7100
# Epoch [8/100] | Train Loss: 0.0578, Train Acc: 0.9975 | Val Loss: 0.6306, Val Acc: 0.7050
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=max, optimizer=RMSProp, epochs=250
# Epoch [1/250] | Train Loss: 0.7235, Train Acc: 0.5500 | Val Loss: 0.6704, Val Acc: 0.6100
# Epoch [2/250] | Train Loss: 0.4956, Train Acc: 0.8113 | Val Loss: 0.6946, Val Acc: 0.5600
# Epoch [3/250] | Train Loss: 0.3778, Train Acc: 0.8762 | Val Loss: 0.6095, Val Acc: 0.6800
# Epoch [4/250] | Train Loss: 0.2647, Train Acc: 0.9463 | Val Loss: 0.6361, Val Acc: 0.6700
# Epoch [5/250] | Train Loss: 0.1724, Train Acc: 0.9800 | Val Loss: 0.6280, Val Acc: 0.6800
# Epoch [6/250] | Train Loss: 0.1369, Train Acc: 0.9838 | Val Loss: 0.6163, Val Acc: 0.6700
# Epoch [7/250] | Train Loss: 0.0761, Train Acc: 0.9975 | Val Loss: 0.6392, Val Acc: 0.6800
# Epoch [8/250] | Train Loss: 0.0592, Train Acc: 0.9975 | Val Loss: 0.6581, Val Acc: 0.6850
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=max, optimizer=RMSProp, epochs=350
# Epoch [1/350] | Train Loss: 0.7679, Train Acc: 0.5262 | Val Loss: 0.6457, Val Acc: 0.6350
# Epoch [2/350] | Train Loss: 0.5092, Train Acc: 0.7762 | Val Loss: 0.6262, Val Acc: 0.6450
# Epoch [3/350] | Train Loss: 0.3941, Train Acc: 0.8675 | Val Loss: 0.6082, Val Acc: 0.6450
# Epoch [4/350] | Train Loss: 0.2813, Train Acc: 0.9413 | Val Loss: 0.6163, Val Acc: 0.6850
# Epoch [5/350] | Train Loss: 0.2167, Train Acc: 0.9500 | Val Loss: 0.6044, Val Acc: 0.6600
# Epoch [6/350] | Train Loss: 0.1322, Train Acc: 0.9925 | Val Loss: 0.6505, Val Acc: 0.6900
# Epoch [7/350] | Train Loss: 0.0904, Train Acc: 0.9988 | Val Loss: 0.6389, Val Acc: 0.6750
# Epoch [8/350] | Train Loss: 0.0632, Train Acc: 1.0000 | Val Loss: 0.6467, Val Acc: 0.6800
# Epoch [9/350] | Train Loss: 0.0421, Train Acc: 1.0000 | Val Loss: 0.6505, Val Acc: 0.6850
# Epoch [10/350] | Train Loss: 0.0341, Train Acc: 1.0000 | Val Loss: 0.6841, Val Acc: 0.6700
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=max, optimizer=Adam, epochs=5
# Epoch [1/5] | Train Loss: 0.7060, Train Acc: 0.5112 | Val Loss: 0.6635, Val Acc: 0.5800
# Epoch [2/5] | Train Loss: 0.5843, Train Acc: 0.7612 | Val Loss: 0.6623, Val Acc: 0.5550
# Epoch [3/5] | Train Loss: 0.5171, Train Acc: 0.7550 | Val Loss: 0.6582, Val Acc: 0.5850
# Epoch [4/5] | Train Loss: 0.4201, Train Acc: 0.8962 | Val Loss: 0.6147, Val Acc: 0.6450
# Epoch [5/5] | Train Loss: 0.3414, Train Acc: 0.9300 | Val Loss: 0.5980, Val Acc: 0.6600
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=max, optimizer=Adam, epochs=50
# ...
# Epoch [45/100] | Train Loss: 0.6744, Train Acc: 0.6125 | Val Loss: 0.6873, Val Acc: 0.5600
# Epoch [46/100] | Train Loss: 0.6741, Train Acc: 0.6188 | Val Loss: 0.6870, Val Acc: 0.5600
# Epoch [47/100] | Train Loss: 0.6739, Train Acc: 0.6162 | Val Loss: 0.6868, Val Acc: 0.5500
# Epoch [48/100] | Train Loss: 0.6736, Train Acc: 0.6250 | Val Loss: 0.6869, Val Acc: 0.5550
# Epoch [49/100] | Train Loss: 0.6733, Train Acc: 0.6175 | Val Loss: 0.6867, Val Acc: 0.5500
# Epoch [50/100] | Train Loss: 0.6730, Train Acc: 0.6200 | Val Loss: 0.6866, Val Acc: 0.5500
# Epoch [51/100] | Train Loss: 0.6728, Train Acc: 0.6225 | Val Loss: 0.6865, Val Acc: 0.5450
# Epoch [52/100] | Train Loss: 0.6726, Train Acc: 0.6288 | Val Loss: 0.6866, Val Acc: 0.5550
# Epoch [53/100] | Train Loss: 0.6722, Train Acc: 0.6188 | Val Loss: 0.6863, Val Acc: 0.5450
# Epoch [54/100] | Train Loss: 0.6719, Train Acc: 0.6262 | Val Loss: 0.6863, Val Acc: 0.5450
# Epoch [55/100] | Train Loss: 0.6717, Train Acc: 0.6162 | Val Loss: 0.6859, Val Acc: 0.5350
# Epoch [56/100] | Train Loss: 0.6713, Train Acc: 0.6225 | Val Loss: 0.6859, Val Acc: 0.5350
# Epoch [57/100] | Train Loss: 0.6712, Train Acc: 0.6312 | Val Loss: 0.6859, Val Acc: 0.5350
# Epoch [58/100] | Train Loss: 0.6707, Train Acc: 0.6362 | Val Loss: 0.6859, Val Acc: 0.5400
# Epoch [59/100] | Train Loss: 0.6706, Train Acc: 0.6200 | Val Loss: 0.6856, Val Acc: 0.5300
# Epoch [60/100] | Train Loss: 0.6702, Train Acc: 0.6312 | Val Loss: 0.6854, Val Acc: 0.5300
# Epoch [61/100] | Train Loss: 0.6699, Train Acc: 0.6225 | Val Loss: 0.6852, Val Acc: 0.5300
# Epoch [62/100] | Train Loss: 0.6695, Train Acc: 0.6362 | Val Loss: 0.6852, Val Acc: 0.5300
# Epoch [63/100] | Train Loss: 0.6693, Train Acc: 0.6300 | Val Loss: 0.6850, Val Acc: 0.5350
# Epoch [64/100] | Train Loss: 0.6690, Train Acc: 0.6338 | Val Loss: 0.6850, Val Acc: 0.5300
# Epoch [65/100] | Train Loss: 0.6687, Train Acc: 0.6362 | Val Loss: 0.6849, Val Acc: 0.5350
# Epoch [66/100] | Train Loss: 0.6684, Train Acc: 0.6275 | Val Loss: 0.6847, Val Acc: 0.5350
# Epoch [67/100] | Train Loss: 0.6682, Train Acc: 0.6338 | Val Loss: 0.6845, Val Acc: 0.5400
# Epoch [68/100] | Train Loss: 0.6678, Train Acc: 0.6288 | Val Loss: 0.6845, Val Acc: 0.5350
# Epoch [69/100] | Train Loss: 0.6675, Train Acc: 0.6350 | Val Loss: 0.6844, Val Acc: 0.5350
# Epoch [70/100] | Train Loss: 0.6671, Train Acc: 0.6312 | Val Loss: 0.6842, Val Acc: 0.5350
# Epoch [71/100] | Train Loss: 0.6668, Train Acc: 0.6262 | Val Loss: 0.6838, Val Acc: 0.5400
# Epoch [72/100] | Train Loss: 0.6665, Train Acc: 0.6388 | Val Loss: 0.6837, Val Acc: 0.5400
# Epoch [73/100] | Train Loss: 0.6661, Train Acc: 0.6400 | Val Loss: 0.6837, Val Acc: 0.5400
# Epoch [74/100] | Train Loss: 0.6659, Train Acc: 0.6388 | Val Loss: 0.6837, Val Acc: 0.5400
# Epoch [75/100] | Train Loss: 0.6654, Train Acc: 0.6375 | Val Loss: 0.6836, Val Acc: 0.5400
# Epoch [76/100] | Train Loss: 0.6650, Train Acc: 0.6450 | Val Loss: 0.6835, Val Acc: 0.5400
# Epoch [77/100] | Train Loss: 0.6647, Train Acc: 0.6412 | Val Loss: 0.6835, Val Acc: 0.5400
# Epoch [78/100] | Train Loss: 0.6644, Train Acc: 0.6388 | Val Loss: 0.6834, Val Acc: 0.5400
# Epoch [79/100] | Train Loss: 0.6640, Train Acc: 0.6438 | Val Loss: 0.6834, Val Acc: 0.5350
# Epoch [80/100] | Train Loss: 0.6638, Train Acc: 0.6388 | Val Loss: 0.6833, Val Acc: 0.5400
# Epoch [81/100] | Train Loss: 0.6633, Train Acc: 0.6388 | Val Loss: 0.6829, Val Acc: 0.5400
# Epoch [82/100] | Train Loss: 0.6629, Train Acc: 0.6475 | Val Loss: 0.6829, Val Acc: 0.5400
# Epoch [83/100] | Train Loss: 0.6626, Train Acc: 0.6488 | Val Loss: 0.6829, Val Acc: 0.5400
# Epoch [84/100] | Train Loss: 0.6623, Train Acc: 0.6338 | Val Loss: 0.6827, Val Acc: 0.5400
# Epoch [85/100] | Train Loss: 0.6620, Train Acc: 0.6450 | Val Loss: 0.6824, Val Acc: 0.5450
# Epoch [86/100] | Train Loss: 0.6618, Train Acc: 0.6450 | Val Loss: 0.6824, Val Acc: 0.5450
# Epoch [87/100] | Train Loss: 0.6611, Train Acc: 0.6375 | Val Loss: 0.6820, Val Acc: 0.5450
# Epoch [88/100] | Train Loss: 0.6608, Train Acc: 0.6462 | Val Loss: 0.6817, Val Acc: 0.5450
# Epoch [89/100] | Train Loss: 0.6604, Train Acc: 0.6438 | Val Loss: 0.6820, Val Acc: 0.5450
# Epoch [90/100] | Train Loss: 0.6600, Train Acc: 0.6475 | Val Loss: 0.6818, Val Acc: 0.5450
# Epoch [91/100] | Train Loss: 0.6598, Train Acc: 0.6462 | Val Loss: 0.6821, Val Acc: 0.5450
# Epoch [92/100] | Train Loss: 0.6592, Train Acc: 0.6462 | Val Loss: 0.6819, Val Acc: 0.5450
# Epoch [93/100] | Train Loss: 0.6590, Train Acc: 0.6462 | Val Loss: 0.6818, Val Acc: 0.5450
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=avg, optimizer=SGD, epochs=250
# Epoch [1/250] | Train Loss: 0.6927, Train Acc: 0.4988 | Val Loss: 0.6955, Val Acc: 0.4700
# Epoch [2/250] | Train Loss: 0.6926, Train Acc: 0.5050 | Val Loss: 0.6956, Val Acc: 0.4700
# Epoch [3/250] | Train Loss: 0.6922, Train Acc: 0.5075 | Val Loss: 0.6954, Val Acc: 0.4750
# Epoch [4/250] | Train Loss: 0.6919, Train Acc: 0.5050 | Val Loss: 0.6954, Val Acc: 0.4750
# Epoch [5/250] | Train Loss: 0.6916, Train Acc: 0.5162 | Val Loss: 0.6954, Val Acc: 0.4700
# Epoch [6/250] | Train Loss: 0.6915, Train Acc: 0.5162 | Val Loss: 0.6954, Val Acc: 0.4700
# Epoch [7/250] | Train Loss: 0.6914, Train Acc: 0.5038 | Val Loss: 0.6954, Val Acc: 0.4700
# Epoch [8/250] | Train Loss: 0.6912, Train Acc: 0.5138 | Val Loss: 0.6954, Val Acc: 0.4700
# Epoch [9/250] | Train Loss: 0.6912, Train Acc: 0.5162 | Val Loss: 0.6954, Val Acc: 0.4750
# Epoch [10/250] | Train Loss: 0.6911, Train Acc: 0.5162 | Val Loss: 0.6954, Val Acc: 0.4750
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=avg, optimizer=SGD, epochs=350
# Epoch [1/350] | Train Loss: 0.6928, Train Acc: 0.5150 | Val Loss: 0.6950, Val Acc: 0.4700
# Epoch [2/350] | Train Loss: 0.6925, Train Acc: 0.5288 | Val Loss: 0.6954, Val Acc: 0.4550
# Epoch [3/350] | Train Loss: 0.6922, Train Acc: 0.5300 | Val Loss: 0.6957, Val Acc: 0.4750
# Epoch [4/350] | Train Loss: 0.6919, Train Acc: 0.5212 | Val Loss: 0.6958, Val Acc: 0.4700
# Epoch [5/350] | Train Loss: 0.6916, Train Acc: 0.5350 | Val Loss: 0.6959, Val Acc: 0.4650
# Epoch [6/350] | Train Loss: 0.6915, Train Acc: 0.5275 | Val Loss: 0.6959, Val Acc: 0.4700
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=avg, optimizer=RMSProp, epochs=5
# Epoch [1/5] | Train Loss: 0.6987, Train Acc: 0.5387 | Val Loss: 0.6859, Val Acc: 0.5100
# Epoch [2/5] | Train Loss: 0.5925, Train Acc: 0.6950 | Val Loss: 0.6455, Val Acc: 0.5800
# Epoch [3/5] | Train Loss: 0.6593, Train Acc: 0.7550 | Val Loss: 0.6325, Val Acc: 0.6150
# Epoch [4/5] | Train Loss: 0.4696, Train Acc: 0.7975 | Val Loss: 0.6119, Val Acc: 0.6650
# Epoch [5/5] | Train Loss: 0.3786, Train Acc: 0.8638 | Val Loss: 0.6217, Val Acc: 0.6500
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=avg, optimizer=RMSProp, epochs=50
# Epoch [1/50] | Train Loss: 0.6861, Train Acc: 0.5763 | Val Loss: 0.6778, Val Acc: 0.5500
# Epoch [2/50] | Train Loss: 0.5819, Train Acc: 0.7137 | Val Loss: 0.6521, Val Acc: 0.6700
# Epoch [3/50] | Train Loss: 0.5084, Train Acc: 0.7738 | Val Loss: 0.6544, Val Acc: 0.6300
# Epoch [4/50] | Train Loss: 0.4077, Train Acc: 0.8187 | Val Loss: 0.6692, Val Acc: 0.6300
# Epoch [5/50] | Train Loss: 0.3397, Train Acc: 0.8488 | Val Loss: 0.6491, Val Acc: 0.6700
# Epoch [6/50] | Train Loss: 0.2926, Train Acc: 0.8850 | Val Loss: 0.6540, Val Acc: 0.7150
# Epoch [7/50] | Train Loss: 0.5899, Train Acc: 0.8612 | Val Loss: 0.6175, Val Acc: 0.7250
# Epoch [8/50] | Train Loss: 0.2400, Train Acc: 0.9000 | Val Loss: 0.6167, Val Acc: 0.7100
# Epoch [9/50] | Train Loss: 0.2322, Train Acc: 0.9012 | Val Loss: 0.5737, Val Acc: 0.7250
# Epoch [10/50] | Train Loss: 0.2891, Train Acc: 0.8888 | Val Loss: 0.5842, Val Acc: 0.6800
# Epoch [11/50] | Train Loss: 0.2700, Train Acc: 0.8875 | Val Loss: 0.5825, Val Acc: 0.6900
# Epoch [12/50] | Train Loss: 0.2271, Train Acc: 0.9150 | Val Loss: 0.5737, Val Acc: 0.7100
# Epoch [13/50] | Train Loss: 0.1937, Train Acc: 0.9287 | Val Loss: 0.6001, Val Acc: 0.7050
# Epoch [14/50] | Train Loss: 0.1767, Train Acc: 0.9313 | Val Loss: 0.5974, Val Acc: 0.6950
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=avg, optimizer=RMSProp, epochs=100
# Epoch [1/100] | Train Loss: 0.6911, Train Acc: 0.5613 | Val Loss: 0.6645, Val Acc: 0.6300
# Epoch [2/100] | Train Loss: 0.6167, Train Acc: 0.7150 | Val Loss: 0.6407, Val Acc: 0.6800
# Epoch [3/100] | Train Loss: 0.6150, Train Acc: 0.7312 | Val Loss: 0.6235, Val Acc: 0.7050
# Epoch [4/100] | Train Loss: 0.4850, Train Acc: 0.7850 | Val Loss: 0.6513, Val Acc: 0.6700
# Epoch [5/100] | Train Loss: 0.4241, Train Acc: 0.8037 | Val Loss: 0.5952, Val Acc: 0.7200
# Epoch [6/100] | Train Loss: 0.4990, Train Acc: 0.8250 | Val Loss: 0.6557, Val Acc: 0.6650
# Epoch [7/100] | Train Loss: 0.3509, Train Acc: 0.8550 | Val Loss: 0.6055, Val Acc: 0.7350
# Epoch [8/100] | Train Loss: 0.3433, Train Acc: 0.8700 | Val Loss: 0.5841, Val Acc: 0.7150
# Epoch [9/100] | Train Loss: 0.2696, Train Acc: 0.8975 | Val Loss: 0.6678, Val Acc: 0.7050
# Epoch [10/100] | Train Loss: 0.2364, Train Acc: 0.9125 | Val Loss: 0.6045, Val Acc: 0.7150
# Epoch [11/100] | Train Loss: 0.2083, Train Acc: 0.9137 | Val Loss: 0.6462, Val Acc: 0.7200
# Epoch [12/100] | Train Loss: 0.1787, Train Acc: 0.9313 | Val Loss: 0.6648, Val Acc: 0.7100
# Epoch [13/100] | Train Loss: 0.1617, Train Acc: 0.9363 | Val Loss: 0.6669, Val Acc: 0.7050
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=avg, optimizer=RMSProp, epochs=250
# Epoch [1/250] | Train Loss: 0.6838, Train Acc: 0.5737 | Val Loss: 0.6741, Val Acc: 0.6100
# Epoch [2/250] | Train Loss: 0.6106, Train Acc: 0.7150 | Val Loss: 0.6591, Val Acc: 0.6150
# Epoch [3/250] | Train Loss: 0.5106, Train Acc: 0.7700 | Val Loss: 1.5918, Val Acc: 0.6700
# Epoch [4/250] | Train Loss: 0.6107, Train Acc: 0.7925 | Val Loss: 0.9217, Val Acc: 0.6650
# Epoch [5/250] | Train Loss: 0.3693, Train Acc: 0.8475 | Val Loss: 0.6818, Val Acc: 0.6300
# Epoch [6/250] | Train Loss: 0.2735, Train Acc: 0.8888 | Val Loss: 0.7842, Val Acc: 0.6100
# Epoch [7/250] | Train Loss: 0.2729, Train Acc: 0.8850 | Val Loss: 0.7935, Val Acc: 0.6350
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=avg, optimizer=RMSProp, epochs=350
# Epoch [1/350] | Train Loss: 0.7119, Train Acc: 0.5925 | Val Loss: 0.6824, Val Acc: 0.5650
# Epoch [2/350] | Train Loss: 0.6023, Train Acc: 0.6950 | Val Loss: 0.6875, Val Acc: 0.6000
# Epoch [3/350] | Train Loss: 0.5799, Train Acc: 0.7375 | Val Loss: 0.6691, Val Acc: 0.6250
# Epoch [4/350] | Train Loss: 0.4651, Train Acc: 0.7800 | Val Loss: 0.7010, Val Acc: 0.6300
# Epoch [5/350] | Train Loss: 0.3865, Train Acc: 0.8350 | Val Loss: 0.6979, Val Acc: 0.6250
# Epoch [6/350] | Train Loss: 0.4725, Train Acc: 0.8275 | Val Loss: 0.6884, Val Acc: 0.6500
# Epoch [7/350] | Train Loss: 0.3004, Train Acc: 0.8825 | Val Loss: 0.7514, Val Acc: 0.6300
# Epoch [8/350] | Train Loss: 0.2717, Train Acc: 0.8962 | Val Loss: 0.7775, Val Acc: 0.6100
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=avg, optimizer=Adam, epochs=5
# Epoch [1/5] | Train Loss: 0.6899, Train Acc: 0.5413 | Val Loss: 0.6861, Val Acc: 0.5400
# Epoch [2/5] | Train Loss: 0.6445, Train Acc: 0.6462 | Val Loss: 0.7731, Val Acc: 0.5700
# Epoch [3/5] | Train Loss: 0.5624, Train Acc: 0.7325 | Val Loss: 0.6309, Val Acc: 0.6650
# Epoch [4/5] | Train Loss: 0.4942, Train Acc: 0.7712 | Val Loss: 0.6097, Val Acc: 0.6750
# Epoch [5/5] | Train Loss: 0.7601, Train Acc: 0.7700 | Val Loss: 0.6664, Val Acc: 0.6600
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=avg, optimizer=Adam, epochs=50
# Epoch [1/50] | Train Loss: 0.6858, Train Acc: 0.5550 | Val Loss: 0.6864, Val Acc: 0.5400
# Epoch [2/50] | Train Loss: 0.6313, Train Acc: 0.6562 | Val Loss: 0.6460, Val Acc: 0.6500
# Epoch [3/50] | Train Loss: 0.5724, Train Acc: 0.7338 | Val Loss: 0.7038, Val Acc: 0.6350
# Epoch [4/50] | Train Loss: 0.4870, Train Acc: 0.7800 | Val Loss: 0.6667, Val Acc: 0.6500
# Epoch [5/50] | Train Loss: 0.3973, Train Acc: 0.8325 | Val Loss: 0.7620, Val Acc: 0.6600
# Epoch [6/50] | Train Loss: 0.3835, Train Acc: 0.8363 | Val Loss: 0.6795, Val Acc: 0.6900
# Epoch [7/50] | Train Loss: 0.3187, Train Acc: 0.8762 | Val Loss: 0.7348, Val Acc: 0.6350
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=avg, optimizer=Adam, epochs=100
# Epoch [1/100] | Train Loss: 0.6926, Train Acc: 0.5587 | Val Loss: 0.6878, Val Acc: 0.6100
# Epoch [2/100] | Train Loss: 0.6438, Train Acc: 0.6587 | Val Loss: 0.7293, Val Acc: 0.5800
# Epoch [3/100] | Train Loss: 0.5629, Train Acc: 0.7175 | Val Loss: 0.6882, Val Acc: 0.5800
# Epoch [4/100] | Train Loss: 0.5290, Train Acc: 0.7550 | Val Loss: 0.7142, Val Acc: 0.5800
# Epoch [5/100] | Train Loss: 0.5013, Train Acc: 0.7538 | Val Loss: 0.6986, Val Acc: 0.6050
# Epoch [6/100] | Train Loss: 0.4555, Train Acc: 0.7788 | Val Loss: 0.6960, Val Acc: 0.6150
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=avg, optimizer=Adam, epochs=250
# Epoch [1/250] | Train Loss: 0.6845, Train Acc: 0.5575 | Val Loss: 0.7031, Val Acc: 0.4700
# Epoch [2/250] | Train Loss: 0.6382, Train Acc: 0.6488 | Val Loss: 0.6878, Val Acc: 0.5600
# Epoch [3/250] | Train Loss: 0.5764, Train Acc: 0.7037 | Val Loss: 0.8053, Val Acc: 0.5850
# Epoch [4/250] | Train Loss: 0.8486, Train Acc: 0.7137 | Val Loss: 1.6735, Val Acc: 0.5450
# Epoch [5/250] | Train Loss: 0.5125, Train Acc: 0.7725 | Val Loss: 0.6560, Val Acc: 0.6100
# Epoch [6/250] | Train Loss: 0.4517, Train Acc: 0.8087 | Val Loss: 0.6396, Val Acc: 0.6350
# Epoch [7/250] | Train Loss: 0.3905, Train Acc: 0.8400 | Val Loss: 0.6295, Val Acc: 0.6750
# Epoch [8/250] | Train Loss: 0.3666, Train Acc: 0.8638 | Val Loss: 0.6289, Val Acc: 0.6500
# Epoch [9/250] | Train Loss: 0.3251, Train Acc: 0.8988 | Val Loss: 0.7162, Val Acc: 0.6700
# Epoch [10/250] | Train Loss: 0.3155, Train Acc: 0.8738 | Val Loss: 0.9373, Val Acc: 0.6300
# Epoch [11/250] | Train Loss: 0.2986, Train Acc: 0.9125 | Val Loss: 0.6966, Val Acc: 0.6900
# Epoch [12/250] | Train Loss: 0.2046, Train Acc: 0.9200 | Val Loss: 0.6772, Val Acc: 0.7150
# Epoch [13/250] | Train Loss: 0.1887, Train Acc: 0.9413 | Val Loss: 0.9399, Val Acc: 0.6850
# Early stopping triggered!
# ================================================
#
# ================================================
# [INFO] hidden_size=128, pooling=avg, optimizer=Adam, epochs=350
# Epoch [1/350] | Train Loss: 0.6861, Train Acc: 0.5513 | Val Loss: 0.6960, Val Acc: 0.5000
# Epoch [2/350] | Train Loss: 0.6254, Train Acc: 0.6987 | Val Loss: 0.7165, Val Acc: 0.5400
# Epoch [3/350] | Train Loss: 0.5576, Train Acc: 0.7325 | Val Loss: 0.6731, Val Acc: 0.6200
# Epoch [4/350] | Train Loss: 0.5999, Train Acc: 0.7500 | Val Loss: 0.7104, Val Acc: 0.5850
# Epoch [5/350] | Train Loss: 0.5113, Train Acc: 0.7500 | Val Loss: 0.7070, Val Acc: 0.5550
# Epoch [6/350] | Train Loss: 0.4845, Train Acc: 0.7625 | Val Loss: 0.6980, Val Acc: 0.6000
# Epoch [7/350] | Train Loss: 0.4340, Train Acc: 0.7963 | Val Loss: 0.7218, Val Acc: 0.6200
# Epoch [8/350] | Train Loss: 0.4066, Train Acc: 0.8337 | Val Loss: 0.7702, Val Acc: 0.6150
# Early stopping triggered!
# ================================================
#
# Hasil eksperimen telah disimpan dalam 'experiment_birnn_results.csv'.
